# %% [markdown]
# # Reading dataset to the python environment

# %%
import pandas as pd

# %%
data=pd.read_excel(r"C:\Users\Dell\Downloads\irisict.xls")

# %%
data.head()
# Out:
#     SL   SW   PL   PW Classification
# 0  5.1  3.5  1.4  0.2    Iris-setosa
# 1  4.9  3.0  1.4  0.2    Iris-setosa
# 2  4.7  3.2  1.3  0.2    Iris-setosa
# 3  4.6  3.1  1.5  0.2    Iris-setosa
# 4  5.0  3.6  1.4  0.2    Iris-setosa

# %% [markdown]
# # Display columns of the dataset

# %%
data.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %% [markdown]
# # Calculating mean of each column in the dataset

# %%
for i in['SL', 'SW', 'PL', 'PW']:
    print(data[i].mean())
# Out:
# 5.843333333333335
# 3.0540000000000007
# 3.7586666666666693
# 1.1986666666666672

# %% [markdown]
# # Checking for null values present in the dataset

# %%
data.isna().sum()
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %% [markdown]
# # Visualisations

# %%
data.hist(rwidth=0.6)
# Out:
# array([[<AxesSubplot:title={'center':'SL'}>,
#         <AxesSubplot:title={'center':'SW'}>],
#        [<AxesSubplot:title={'center':'PL'}>,
#         <AxesSubplot:title={'center':'PW'}>]], dtype=object)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,6))
plt.scatter(data['SL'],data['PL'])
plt.title("SL vs PL",fontsize=16)
plt.xlabel("Sepal Length")
plt.ylabel("Petal Length")
plt.show()

# %%
import seaborn as sns
sns.pairplot(data)

# %%
plt.figure(figsize=(8,6))
sns.heatmap(data.corr(),annot=True)
plt.show()
